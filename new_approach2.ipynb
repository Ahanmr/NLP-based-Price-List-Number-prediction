# %%
import re
import pandas as pd
from nltk import word_tokenize
# df=pd.read_csv("test_sih.csv - Sheet1.csv")
# df.head(6)
test=str("hello! this is amazing #sih2019 [rcoer]")
print(word_tokenize(test))
test=re.sub('\W+',' ', test )
# import nltk

print(word_tokenize(test))
# Out:
# ['hello', '!', 'this', 'is', 'amazing', '#', 'sih2019', '[', 'rcoer', ']']
# ['hello', 'this', 'is', 'amazing', 'sih2019', 'rcoer']

# %%
df=pd.read_csv("test_sih.csv - Sheet1.csv")
df.head()
# Out:
#    SLNO    PL No.                                        DESCRIPTION
# 0     1  11020179  Suspension motor nose holder with sandwitch mo...
# 1     2  11020416                     SAFETY BRACKET EQUALIGING BEAM
# 2     3  11020453                               SLACK ADJUSTER UPPER
# 3     4  11020519                     EQUALISER LINKAGE WITH BUSHING
# 4     5  11020544  ADJUSTER SLACK LONG ASSLY (WEDER HORN TRUCK BO...

# %%
df["DESCRIPTION"][0].lower()
# Out:
# 'suspension motor nose holder with sandwitch mounting'

# %%
df["TAGS"]=df["DESCRIPTION"]
for i in range(len(df["DESCRIPTION"])):
    df["TAGS"][i]=df["TAGS"][i].lower()
    df["TAGS"][i]=re.sub('\W+',' ', df["TAGS"][i])
    df["TAGS"][i]=word_tokenize(df["TAGS"][i])

df.head(6)
# Out:
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ahanmr/flipkart/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    SLNO    PL No.                                        DESCRIPTION  \
# 0     1  11020179  Suspension motor nose holder with sandwitch mo...
# 1     2  11020416                     SAFETY BRACKET EQUALIGING BEAM
# 2     3  11020453                               SLACK ADJUSTER UPPER
# 3     4  11020519                     EQUALISER LINKAGE WITH BUSHING
# 4     5  11020544  ADJUSTER SLACK LONG ASSLY (WEDER HORN TRUCK BO...
# 5     6  11020568                                       HANGER LEVER
#
#                                                 TAGS
# 0  [suspension, motor, nose, holder, with, sandwi...
# 1                [safety, bracket, equaliging, beam]
# 2                           [slack, adjuster, upper]
# 3                [equaliser, linkage, with, bushing]
# 4  [adjuster, slack, long, assly, weder, horn, tr...
# 5                                    [hanger, lever]

# %%
df.head(20)
# Out:
#     SLNO    PL No.                                        DESCRIPTION  \
# 0      1  11020179  Suspension motor nose holder with sandwitch mo...
# 1      2  11020416                     SAFETY BRACKET EQUALIGING BEAM
# 2      3  11020453                               SLACK ADJUSTER UPPER
# 3      4  11020519                     EQUALISER LINKAGE WITH BUSHING
# 4      5  11020544  ADJUSTER SLACK LONG ASSLY (WEDER HORN TRUCK BO...
# 5      6  11020568                                       HANGER LEVER
# 6      7  11020581            HANGER INSIDE FOR BRAKE FOUNDATION (BG)
# 7      8  11020600             HANGER ASSLY BRAKE FOUNDATION OUT SIDE
# 8      9  11020611                       EQUALISER SLACK ADJUSTER PIN
# 9     10  11020623                  TIE BAR FOR BRAKE FOUNDATION WDM2
# 10    11  11026248               Rubber Buffer Pad DLW PT No.11026248
# 11    12  11029869  LINKAGE EQULISER WITH BUSHING FOR BRAKE FOUNDA...
# 12    13  11029973                SLACK ADJUSTER ASSEMBLY TOP , WDG3A
# 13    14  11030227           HIGH TENSILE CENTRE BUFFER COUPLER ASSLY
# 14    15  11030434  15 KJ High Capacity Loco Side Buffer Assembly ...
# 15    16  11032091   MODIFIED TRANSITION SCREW COUPLING FOR WDM2 LOCO
# 16    17  11032376                         Cattle Guard for WDM2 LOCO
# 17    18  11033617  PLATE TYPE CATTLE GUARD ASSEMBLY, DLW PT NO.11...
# 18    19  11064286  BUSH AND DUMBLE VALVE ASSLY FOR VA-IBCONTROL V...
# 19    20  11064500               COCK ANGLE 1.1/4 INCH WITH VENT B.P,
#
#                                                  TAGS
# 0   [suspension, motor, nose, holder, with, sandwi...
# 1                 [safety, bracket, equaliging, beam]
# 2                            [slack, adjuster, upper]
# 3                 [equaliser, linkage, with, bushing]
# 4   [adjuster, slack, long, assly, weder, horn, tr...
# 5                                     [hanger, lever]
# 6        [hanger, inside, for, brake, foundation, bg]
# 7       [hanger, assly, brake, foundation, out, side]
# 8                   [equaliser, slack, adjuster, pin]
# 9            [tie, bar, for, brake, foundation, wdm2]
# 10       [rubber, buffer, pad, dlw, pt, no, 11026248]
# 11  [linkage, equliser, with, bushing, for, brake,...
# 12            [slack, adjuster, assembly, top, wdg3a]
# 13    [high, tensile, centre, buffer, coupler, assly]
# 14  [15, kj, high, capacity, loco, side, buffer, a...
# 15  [modified, transition, screw, coupling, for, w...
# 16                   [cattle, guard, for, wdm2, loco]
# 17  [plate, type, cattle, guard, assembly, dlw, pt...
# 18  [bush, and, dumble, valve, assly, for, va, ibc...
# 19     [cock, angle, 1, 1, 4, inch, with, vent, b, p]

# %%
df
# Out:
#      SLNO    PL No.                                        DESCRIPTION  \
# 0       1  11020179  Suspension motor nose holder with sandwitch mo...
# 1       2  11020416                     SAFETY BRACKET EQUALIGING BEAM
# 2       3  11020453                               SLACK ADJUSTER UPPER
# 3       4  11020519                     EQUALISER LINKAGE WITH BUSHING
# 4       5  11020544  ADJUSTER SLACK LONG ASSLY (WEDER HORN TRUCK BO...
# 5       6  11020568                                       HANGER LEVER
# 6       7  11020581            HANGER INSIDE FOR BRAKE FOUNDATION (BG)
# 7       8  11020600             HANGER ASSLY BRAKE FOUNDATION OUT SIDE
# 8       9  11020611                       EQUALISER SLACK ADJUSTER PIN
# 9      10  11020623                  TIE BAR FOR BRAKE FOUNDATION WDM2
# 10     11  11026248               Rubber Buffer Pad DLW PT No.11026248
# 11     12  11029869  LINKAGE EQULISER WITH BUSHING FOR BRAKE FOUNDA...
# 12     13  11029973                SLACK ADJUSTER ASSEMBLY TOP , WDG3A
# 13     14  11030227           HIGH TENSILE CENTRE BUFFER COUPLER ASSLY
# 14     15  11030434  15 KJ High Capacity Loco Side Buffer Assembly ...
# 15     16  11032091   MODIFIED TRANSITION SCREW COUPLING FOR WDM2 LOCO
# 16     17  11032376                         Cattle Guard for WDM2 LOCO
# 17     18  11033617  PLATE TYPE CATTLE GUARD ASSEMBLY, DLW PT NO.11...
# 18     19  11064286  BUSH AND DUMBLE VALVE ASSLY FOR VA-IBCONTROL V...
# 19     20  11064500               COCK ANGLE 1.1/4 INCH WITH VENT B.P,
# 20     21  11121002  Side wear plate for centre pivot, DLW Pt No.11...
# 21     22  11121014  Bottom Wear plate for center pivot DLW Pt No.1...
# 22     23  11123126  SIDE WEAR PLATE FOR BOLSTEREr Drg No.11123126 ...
# 23     24  11123140  FACE LINER FOR MOTOR TRUCK (WH & NH ) &AXLE BO...
# 24     25  11123151      LUG LINER FOR MOTOR TRUCK W.H.& NH 200X35X4MM
# 25     26  11123175                       EQUALISER BEAM LONG W.H. STD
# 26     27  11123199                            EQUALISER SHORT W.H.STD
# 27     28  11123308                     WEAR PTATE BOLESTER HORIZENTAL
# 28     29  11123539     WEAR PLATE LOADING PAD MOTOR TRUCK (ELIPTICAL)
# 29     30  11128380  LINER PEDESTAL FACE FOR BOGIE FRAME, DLW Pt No...
# ..    ...       ...                                                ...
# 112   113  11445555  4 inch Control AIR GUAGE self illuminated with...
# 113   114  11454052  ROTEX VALVE 2 WAY MAGNET VALVE NORMALLY OPENED...
# 114   115  11454635      HORN AND AXLE BOX FACE LINER FOR WDG3A LOCOS,
# 115   116  11454647  HORN AND AXLE BOX SIDE LINER , MIN. STEEL FOR ...
# 116   117  11456530                      WIPER ASSLY 12 inch FOR WDG3A
# 117   118  11456541                       WIPER ASSLY 8 inch FOR WDG3A
# 118   119  11457156  ROTEX VALVE TWO WAY MAGNET VALVE NORMALLY CLOS...
# 119   120  11459025  Hydraulic damper (Latral) for WDG3A, RDSO Drg ...
# 120   121  11459037  Hydraulic Damper Vertical for WDG3A RDSO Drg N...
# 121   122  11459815        PRESSURE SWITCH RT-116,DLW Part No.11459815
# 122   123  11485085  AIR FLOW MEASURING VALVE ASSLY (50 percent pan...
# 123   124  11487513      C3W DISTRIBUTOR VALVE with control reservoir,
# 124   125  11487586          PRESSURE SWITCH RT-5X DLW Pt no.11487586.
# 125   126  11520267  LINK FOR WDG3A, Locos to RDSO Spec No. MP.0.49...
# 126   127  11520279  Equiliser beam for WDG3A,RDSO Spec.No.- MP.0.4...
# 127   128  11520280                       Compensating Beam for WDG3A,
# 128   129  11520360  BRAKE RIGGING KIT FOR WDG3A/WDM3D Locos, DLW P...
# 129   130  11665580             DIAPHRAGM SMALL FOR VA1B CONTROL VALVE
# 130   131  11665660  VERTICAL HYDRAULIC DAMPER for WDM3D RDSO DRG N...
# 131   132  11981179                         HANGING BOLT FOR GEAR CASE
# 132   133  11981556                             FEED VALVE F2 MODIFIED
# 133   134  11981581  RUBBER PART KIT FOR D24B FEED VALVE CONSISTING...
# 134   135  11981799  REPAIR KIT FOR AIR FLOW MEASURING VALVE consis...
# 135   136  11981945  RUBBER KIT FOR D-1 EMERGENCY VALVE it Consist ...
# 136   137  11984259         SAFETY CLAMP FOR TRANSITION SCREW COUPLING
# 137   138  11990235  KIT FOR DESSICANT CANISTER SIL PART NO.RK-AB-7...
# 138   139  11990247                         PIPING ASSLY FOR AIR DRYER
# 139   140  11990260                                KIT FOR PURGE VALVE
# 140   141  11990272          KIT FOR INLET CHECK VALVE RK-AB-787-W-27A
# 141   142  11990296                    TIMER CIRCUIT BOARD(NON MEMORY)
#
#                                                   TAGS
# 0    [suspension, motor, nose, holder, with, sandwi...
# 1                  [safety, bracket, equaliging, beam]
# 2                             [slack, adjuster, upper]
# 3                  [equaliser, linkage, with, bushing]
# 4    [adjuster, slack, long, assly, weder, horn, tr...
# 5                                      [hanger, lever]
# 6         [hanger, inside, for, brake, foundation, bg]
# 7        [hanger, assly, brake, foundation, out, side]
# 8                    [equaliser, slack, adjuster, pin]
# 9             [tie, bar, for, brake, foundation, wdm2]
# 10        [rubber, buffer, pad, dlw, pt, no, 11026248]
# 11   [linkage, equliser, with, bushing, for, brake,...
# 12             [slack, adjuster, assembly, top, wdg3a]
# 13     [high, tensile, centre, buffer, coupler, assly]
# 14   [15, kj, high, capacity, loco, side, buffer, a...
# 15   [modified, transition, screw, coupling, for, w...
# 16                    [cattle, guard, for, wdm2, loco]
# 17   [plate, type, cattle, guard, assembly, dlw, pt...
# 18   [bush, and, dumble, valve, assly, for, va, ibc...
# 19      [cock, angle, 1, 1, 4, inch, with, vent, b, p]
# 20   [side, wear, plate, for, centre, pivot, dlw, p...
# 21   [bottom, wear, plate, for, center, pivot, dlw,...
# 22   [side, wear, plate, for, bolsterer, drg, no, 1...
# 23   [face, liner, for, motor, truck, wh, nh, axle,...
# 24   [lug, liner, for, motor, truck, w, h, nh, 200x...
# 25                  [equaliser, beam, long, w, h, std]
# 26                       [equaliser, short, w, h, std]
# 27                 [wear, ptate, bolester, horizental]
# 28   [wear, plate, loading, pad, motor, truck, elip...
# 29   [liner, pedestal, face, for, bogie, frame, dlw...
# ..                                                 ...
# 112  [4, inch, control, air, guage, self, illuminat...
# 113  [rotex, valve, 2, way, magnet, valve, normally...
# 114  [horn, and, axle, box, face, liner, for, wdg3a...
# 115  [horn, and, axle, box, side, liner, min, steel...
# 116               [wiper, assly, 12, inch, for, wdg3a]
# 117                [wiper, assly, 8, inch, for, wdg3a]
# 118  [rotex, valve, two, way, magnet, valve, normal...
# 119  [hydraulic, damper, latral, for, wdg3a, rdso, ...
# 120  [hydraulic, damper, vertical, for, wdg3a, rdso...
# 121  [pressure, switch, rt, 116, dlw, part, no, 114...
# 122  [air, flow, measuring, valve, assly, 50, perce...
# 123  [c3w, distributor, valve, with, control, reser...
# 124  [pressure, switch, rt, 5x, dlw, pt, no, 11487586]
# 125  [link, for, wdg3a, locos, to, rdso, spec, no, ...
# 126  [equiliser, beam, for, wdg3a, rdso, spec, no, ...
# 127                   [compensating, beam, for, wdg3a]
# 128  [brake, rigging, kit, for, wdg3a, wdm3d, locos...
# 129      [diaphragm, small, for, va1b, control, valve]
# 130  [vertical, hydraulic, damper, for, wdm3d, rdso...
# 131                   [hanging, bolt, for, gear, case]
# 132                        [feed, valve, f2, modified]
# 133  [rubber, part, kit, for, d24b, feed, valve, co...
# 134  [repair, kit, for, air, flow, measuring, valve...
# 135  [rubber, kit, for, d, 1, emergency, valve, it,...
# 136  [safety, clamp, for, transition, screw, coupling]
# 137  [kit, for, dessicant, canister, sil, part, no,...
# 138                   [piping, assly, for, air, dryer]
# 139                           [kit, for, purge, valve]
# 140  [kit, for, inlet, check, valve, rk, ab, 787, w...
# 141               [timer, circuit, board, non, memory]
#
# [142 rows x 4 columns]

# %%
df.to_csv("DATA.csv")

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances

# %%
corpus=[]
for i in range(len(df["DESCRIPTION"])):
    corpus.append(df["DESCRIPTION"][i])

# %%
# vectorizer=CountVectorizer()
# features=vectorizer.fit_transform(corpus).todense()
# print(features)

# %%
# vectorizer.vocabulary_

# %%
# featurelist=features.tolist()

# %%
# import numpy as np
# featurelist[0]=np.array(featurelist[0])
# featurelist[1]=np.array(featurelist[1])
# sum(abs(featurelist[0]-featurelist[3]))
